# %% [markdown]
# # 06 Model Comparison
#
# This notebook compares the clean application models with the behavioral and full diagnostic variants.

# %%
from pathlib import Path
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Image

ROOT = Path.cwd()
REPORTS = ROOT / 'reports'
MODELS = ROOT / 'models'
DATA_PATH = next((ROOT / 'data' / 'raw').glob('*'))
pd.set_option('display.max_columns', 100)
sns.set_theme(style='whitegrid')

comparison = pd.read_csv(REPORTS / 'model_validation' / 'clean_feature_model_comparison.csv')
display(comparison)

# %%
plot_df = comparison[['model_name', 'roc_auc', 'accuracy']].copy()
fig, ax = plt.subplots(figsize=(10, 4))
plot_df.set_index('model_name')['roc_auc'].sort_values().plot(kind='barh', ax=ax, color='#457b9d')
ax.set_title('ROC-AUC by Model Variant')
ax.set_xlabel('ROC-AUC')
plt.tight_layout()

# %% [markdown]
# The near-perfect behavioral and full-diagnostic XGBoost results are retained as diagnostic references only. They should not be presented as the final loan approval model because they rely on post-loan information.
