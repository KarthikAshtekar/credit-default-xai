# %% [markdown]
# # 06 Model Comparison\nCompare Logistic Regression and XGBoost performance.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import pandas as pd
import numpy as np

# %%
import json
from pathlib import Path

base = Path("../reports/fairness_reports") if Path.cwd().name == "notebooks" else Path("reports/fairness_reports")
log_path = base / "logistic_metrics.json"
xgb_path = base / "xgboost_metrics.json"

with open(log_path, "r", encoding="utf-8") as f:
    log = json.load(f)["metrics"]
with open(xgb_path, "r", encoding="utf-8") as f:
    xgb = json.load(f)["metrics"]

pd.DataFrame([log, xgb], index=["Logistic", "XGBoost"])
