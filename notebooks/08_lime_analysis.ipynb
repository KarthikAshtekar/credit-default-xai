# %% [markdown]
# # 08 LIME Analysis
#
# LIME provides a local approximation of the final model around one applicant, complementing the SHAP analysis.

# %%
from pathlib import Path
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Image

ROOT = Path.cwd()
REPORTS = ROOT / 'reports'
MODELS = ROOT / 'models'
DATA_PATH = next((ROOT / 'data' / 'raw').glob('*'))
pd.set_option('display.max_columns', 100)
sns.set_theme(style='whitegrid')
def load_json(path: Path):
    with open(path, 'r', encoding='utf-8') as handle:
        return json.load(handle)

def show_image_if_exists(path: Path, width: int = 900):
    if path.exists():
        display(Image(filename=str(path), width=width))
    else:
        print(f'Missing image: {path}')

show_image_if_exists(REPORTS / 'explainability_reports' / 'application_model' / 'xgboost_application_lime_local.png')

# %% [markdown]
# The LIME chart highlights which application-time features most increased or decreased the predicted probability for one local example. In presentation settings, LIME is useful for discussing individual decisions in plain language.
